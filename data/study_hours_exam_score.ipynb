# %% [markdown]
# Improting  the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Importing the dataset

# %%
dataset = pd.read_csv('study_hours_exam_score.csv')
x = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %% [markdown]
# Training the Linear Regression Model on whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# Training the Polynomial Regression Model on whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=2)
x_poly = poly_reg.fit_transform(x)
lin_reg2 = LinearRegression()
lin_reg2.fit(x_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# Visualising the Results of Linear regression

# %%
plt.scatter(x, y, color='red')
plt.plot(x, lin_reg.predict(x), color = 'blue')
plt.title('study hours vs score (Linear Regression)')
plt.xlabel('study hours')
plt.ylabel('score')
plt.show()

# %% [markdown]
# Visualising the results of Polynomial Regression

# %%
plt.scatter(x, y, color='red')
plt.plot(x,lin_reg2.predict(x_poly), color='blue')
plt.title('study hours vs score (Polynomial Regression)')
plt.xlabel('study hours')
plt.ylabel('score')
plt.show()

# %% [markdown]
# Predicting the Linear Regression Model Result

# %%
lin_reg.predict([[1]])
# Out:
# array([75.31925323])

# %% [markdown]
# Predicting the Polynomial Regression Model Results

# %%
lin_reg2.predict(poly_reg.transform([[1]]))
# Out:
# array([50.10834212])
